# %%
from pathlib import Path
import os
from scportrait.pipeline.project import Project

# %%
# Directory containing *_BF.tif files to process.
cwd = os.getcwd()


INPUT_DIR: Path = (
    Path(cwd).resolve().parents[0]
    / "data"
    / "Plate 2426_new_preprocessed_2D_split"
    / "subset"
)

# Root output directory; one subdirectory is created per input sample.
PROJECT_DIR: Path = (
    Path(cwd).resolve().parents[0] / "tmp" / "scportrait_bf_pipeline"
)

# Path to the scPortrait config YAML (same directory as this script).
CONFIG_PATH: Path = Path(cwd).resolve() / "config.yml"


PROJECT_DIR
# Out:
# PosixPath('/Users/serenasritharan/Projects/single-cell/tmp/scportrait_bf_pipeline')

# %%
sample_name = "p2426_B01_z10_BF"
sample_project_dir = PROJECT_DIR / sample_name

project = Project(
    str(sample_project_dir),
    config_path=str(CONFIG_PATH),
    overwrite=False,
    # overwrite=True,
    # segmentation_f=CytosolOnlySegmentationCellpose,
    # extraction_f=HDF5CellExtraction,
    # # featurization_f=MLClusterClassifier,    # <-- Needs custom featurizer for BF-only input; change to CellFeaturizer for a simple baseline.
    # featurization_f=CellFeaturizer,  # <-- change this
)
# Out:
# /var/folders/xn/vsqnhgdd4zdbrg1_47j52jk00000gn/T/ipykernel_1812/3649700126.py:4: UserWarning: There is already a directory in the location path
#   project = Project(
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# Updating project config file.
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)

# %%
# View everything in napari (segmentation overlaid on input image)
project.view_sdata()
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# 2026-03-20 13:33:01.070 | WARNING  | napari_spatialdata._viewer:__init__:57 - Due to Shift-L being used as shortcut in napari, it is being deprecated and might not link a new layer to an existing SpatialData object in the viewer. Please use ⌘-L on MacOS or else Ctrl-L.
# 2026-03-20 13:33:12.301 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:12.302 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:15.822 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:15.825 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:15.870 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-03-20 13:33:44.247 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:44.250 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:54.914 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:54.922 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:54.924 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:56.041 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:56.048 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:56.103 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:57.139 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:57.143 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:57.958 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:57.962 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:58.096 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:58.129 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:58.993 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.035 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.069 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.153 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.153 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.692 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.694 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:33:59.698 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:34:03.988 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:34:03.989 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:34:49.269 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:34:49.272 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:34:49.317 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:06.214 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:06.217 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:33.575 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:33.581 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:33.623 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:34.959 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:34.964 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:34.966 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:35.577 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:35.583 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:35:35.621 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /opt/anaconda3/envs/single-cell-env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-03-20 13:36:11.172 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:11.207 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:11.242 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:11.351 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:11.351 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:14.068 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:14.071 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-03-20 13:36:14.105 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.

# %%
# When done:
project.close_interactive_viewer()
